# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`

# %%
employee = pd.read_csv('Employee.csv')
employee.head(1)
# Out:
#    Name Department Education Gender    Title  Years  Salary
# 0  Jose         IT  Bachelor      M  analyst      1      35

# %% [markdown]
# #### What's the mean salary by department.
# ##### Tip : There are 2 ways to do it - one way is with and the other way is without pivot tables. Do it both ways.

# %%
employee.pivot_table(index = 'Department', values= 'Salary', aggfunc= 'mean')
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %%
employee.groupby('Department').mean().iloc[:,1:]
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title

# %%
employee.pivot_table(index = ['Department', 'Title'], values= 'Salary', aggfunc= 'mean')
# Out:
#                       Salary
# Department Title
# HR         VP           70.0
#            analyst      32.5
# IT         VP           70.0
#            analyst      32.5
#            associate    60.0
# Sales      associate    55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
employee.pivot_table(index = ['Title', 'Years'], values= 'Salary', aggfunc= 'mean')
# Out:
#                  Salary
# Title     Years
# VP        8          70
# analyst   1          35
#           2          30
#           4          35
# associate 2          55
#           3          55
#           7          60

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title

# %%
employee.pivot_table(index = ['Department','Title'], values= 'Salary', aggfunc= {'Salary' : 'mean','Title' : 'count'})
# Out:
#                       Salary  Title
# Department Title
# HR         VP           70.0      1
#            analyst      32.5      2
# IT         VP           70.0      1
#            analyst      32.5      2
#            associate    60.0      1
# Sales      associate    55.0      2

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median,minimum,maximum and standard deviation. Comment your results

# %%
piv = employee.pivot_table(index = ['Department','Title'], values= 'Salary', aggfunc= ['median', 'min', 'max', 'std'])
piv
# std can't be calculated in some occasions as only one value
# Out:
#                      median    min    max       std
#                      Salary Salary Salary    Salary
# Department Title
# HR         VP          70.0     70     70       NaN
#            analyst     32.5     30     35  3.535534
# IT         VP          70.0     70     70       NaN
#            analyst     32.5     30     35  3.535534
#            associate   60.0     60     60       NaN
# Sales      associate   55.0     55     55  0.000000

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value

# %%
piv.fillna(value = 0, inplace = True)
piv
# Out:
#                      median    min    max       std
#                      Salary Salary Salary    Salary
# Department Title
# HR         VP          70.0     70     70  0.000000
#            analyst     32.5     30     35  3.535534
# IT         VP          70.0     70     70  0.000000
#            analyst     32.5     30     35  3.535534
#            associate   60.0     60     60  0.000000
# Sales      associate   55.0     55     55  0.000000

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
employee.pivot_table(index = ['Department'], values= 'Salary', aggfunc= {'Salary' : 'sum', 'Department': 'count' })
# Out:
#             Department  Salary
# Department
# HR                   3     135
# IT                   4     195
# Sales                2     110

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary

# %%
employee.pivot_table(index = ['Department', 'Title'], values= ['Salary', 'Years'], aggfunc= {'Years' : 'sum', 'Salary': 'mean' })
# Out:
#                       Salary  Years
# Department Title
# HR         VP           70.0      8
#            analyst      32.5      6
# IT         VP           70.0      8
#            analyst      32.5      3
#            associate    60.0      7
# Sales      associate    55.0      5

# %% [markdown]
# #### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table
#
# #### * Hint: Write a custom function*

# %%
employee.pivot_table(index = ['Department'], values= ['Salary'], aggfunc= ['count','max' ])
# Out:
#             count    max
#            Salary Salary
# Department
# HR              3     70
# IT              4     70
# Sales           2     55

# %%
def bonus(lst):
    return lst.remove(max(lst)) / len(lst)

# %%
lst = [70,70,55]

bonus(lst)
lst
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16628\1315892096.py in <module>
#       1 lst = [70,70,55]
#       2
# ----> 3 bonus(lst)
#       4 lst
#
# ~\AppData\Local\Temp\ipykernel_16628\2493978980.py in bonus(lst)
#       1 def bonus(lst):
# ----> 2     return lst.remove(max(lst)) / len(lst)
#
# TypeError: unsupported operand type(s) for /: 'NoneType' and 'int'

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Open the ` Fitbit.csv` file and name your dataset `fitbit`

# %%
fitbit = pd.read_csv('Fitbit.csv')

# %% [markdown]
# #### Explore you dataset in terms of data types and descriptive statistics
# #### *Hint: Use Pandas functions from previous lectures*

# %%
fitbit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    367 non-null    object
#  1   Calorie burned          367 non-null    int64
#  2   Steps                   367 non-null    int64
#  3   Distance                367 non-null    float64
#  4   Floors                  367 non-null    int64
#  5   Minutes Sedentary       367 non-null    float64
#  6   Minutes Lightly Active  367 non-null    int64
#  7   Minutes Fairly Active   367 non-null    int64
#  8   Minutes Very Active     367 non-null    int64
#  9   Activity Calories       367 non-null    int64
#  10  MinutesOfSleep          367 non-null    int64
#  11  MinutesOfBeingAwake     367 non-null    int64
#  12  NumberOfAwakings        367 non-null    int64
#  13  LengthOfRestInMinutes   367 non-null    int64
# ...

# %%
fitbit.describe().T
# Out:
#                         count          mean          std      min       25%  \
# Calorie burned          367.0   2741.501362   916.307036  179.000  2698.000
# Steps                   367.0  10121.588556  5594.836225    0.000  6730.500
# Distance                367.0      8.549128     3.409881    0.000     6.155
# Floors                  367.0     11.724796    10.337370    0.000     5.000
# Minutes Sedentary       367.0    563.934482   294.793145    1.002   520.000
# Minutes Lightly Active  367.0    236.405995    86.531376    0.000   179.000
# Minutes Fairly Active   367.0     26.163488    20.319456    0.000     8.000
# Minutes Very Active     367.0     35.722071    31.006682    0.000    10.500
# Activity Calories       367.0   2044.147139  2041.267168    0.000  1218.500
# MinutesOfSleep          367.0    290.479564   154.752328    0.000   224.000
# MinutesOfBeingAwake     367.0     28.008174    18.541415    0.000    14.000
# ...

# %% [markdown]
# #### You suspect that there must be a linear relationship between the Minutes Very Active and the Steps. Compute the correlation between these variables.

# %%
fitbit[['Minutes Very Active','Steps']].corr()
# Out:
#                      Minutes Very Active     Steps
# Minutes Very Active             1.000000  0.571452
# Steps                           0.571452  1.000000

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Very active vs Steps.
#
# ##### Hint : import matplotlib.pyplot as plt (See previous lessons)#####
# - Use plt.scatter(x=df['col_name_1'], y=df['col_name_2'])

# %%
import pylab as plt
#import matplotlib.pyplot as plt

plt.scatter(x=fitbit['Minutes Very Active'], y = fitbit['Steps'] )

# %% [markdown]
# #### What can you say about Minute Very Active and Steps? Write a comment below

# %%
#Many are active very few minutes but have many steps. 
# Mant have very few steps despite beeing very active many minutes.

# Thus: Many outliers. For the others, the correlation is flagrant.

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the Minutes Sedentary and the Steps. Compute the correlation between these variables.

# %%
fitbit[['Minutes Sedentary','Steps']].corr()
# Out:
#                    Minutes Sedentary     Steps
# Minutes Sedentary           1.000000  0.076906
# Steps                       0.076906  1.000000

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Sedentary vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
import pylab as plt
#import matplotlib.pyplot as plt

plt.scatter(x=fitbit['Minutes Sedentary'], y = fitbit['Steps'] )

# %%
# Close to none correlation

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the MinutesOfSleep and the Steps. Compute the correlation between these variables.

# %%
fitbit[['MinutesOfSleep','Steps']].corr()
# Out:
#                 MinutesOfSleep     Steps
# MinutesOfSleep        1.000000  0.130986
# Steps                 0.130986  1.000000

# %% [markdown]
# #### Use matplotlib to visually plot MinutesOfSleep vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
import pylab as plt
#import matplotlib.pyplot as plt

plt.scatter(x=fitbit['MinutesOfSleep'], y = fitbit['Steps'] );

# %% [markdown]
# #### Select a subset of your dataset with the columns below and compute the correlation matrix. Save the results in the variable `cor_fit`
# column= ['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']

# %%
column= ['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']

# %%
pd.plotting.scatter_matrix(fitbit[column]._get_numeric_data(), figsize=(15, 8));

# %% [markdown]
# #### Based on the result of the correlation matrix. What are the highly correlated features with the variable Steps?
# *Hint: From the results above select the variable Steps and order your results in descending order (use Pandas sort_values function)*

# %%
#Calorie Burned, Floors and Minutes very active

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the `Time_Grades.csv` file and name your dataset `time_grades`

# %%
time_grades = pd.read_csv('Time_Grades.csv')

# %%
time_grades.head()
# Out:
#      Name  Study time  Grade
# 0    Jose           4      4
# 1   Maria           9      7
# 2   David           8      9
# 3   Sonia          10      7
# 4  Samuel          20      9

# %% [markdown]
# #### Show visually the frequency distribution of the time_grades dataset.

# %%
time_grades.plot(kind='bar',
                    figsize=(8, 4),
                    color=['black','g'],  
                    grid=True)

plt.show();

# %% [markdown]
# #### Is there a correaltion between study time and Grade? Use both Pearson and Spearman correlation and comment your results.

# %%
import scipy.stats as st

# %%
st.pearsonr(time_grades['Study time'], time_grades['Grade']), st.spearmanr(time_grades['Study time'], time_grades['Grade']),
# Out:
# (PearsonRResult(statistic=0.7980456073578859, pvalue=0.0003627635256342718),
#  SpearmanrResult(correlation=0.819658753036942, pvalue=0.00018377469445788485))

# %% [markdown]
# #### Use matplotlib to visually plot Study time vs Grade. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
plt.scatter(x=time_grades['Study time'], y = time_grades['Grade'] );

# %%
#They are correlated

# %% [markdown]
# #### Could you explain the difference between Pearson and Spearman correlation? (see References in README.md)

# %%
'''The fundamental difference between the two correlation coefficients is that 
the Pearson coefficient works with a linear relationship between the two variables 
whereas the Spearman Coefficient works with monotonic relationships as well.

El coeficiente de correlación de Spearman se basa en los valores jerarquizados de cada variable y no en los datos sin procesar. 
La correlación de Spearman suele utilizarse para evaluar relaciones en las que intervienen variables ordinales. 
'''
